# %% [markdown]
# # Rock, Paper, Scissor Recognition
# <body>
# Khairullah Ilyas<br>
# Kab.Agam, Sumatera Barat
# </body>

# %% [markdown]
# ### Import Library

# %%
import tensorflow as tf
import zipfile
import os
import requests
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
if tf.test.gpu_device_name():
    print("GPU device found")
else:
    print("No GPU device found")
# Out:
# GPU device found

# %% [markdown]
# ## Extract Data

# %%
url = 'https://github.com/dicodingacademy/assets/releases/download/release/rockpaperscissors.zip'
file_path = 'rockpaperscissors.zip'

# Download zip file
response = requests.get(url)
with open(file_path, 'wb') as f:
    f.write(response.content)

# %%
# Extract zip file
with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall()

# %%
# Labelling Classes
labels = ['paper','scissors','rock']
nb = len(labels) # Number of classes

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
def input_target_split(train_dir,labels):
    dataset = []
    count = 0
    for label in labels:
        folder = os.path.join(train_dir,label)
        for image in os.listdir(folder):
            img=load_img(os.path.join(folder,image), target_size=(150,150))
            img=img_to_array(img)
            img=img/255.0
            dataset.append((img,count))
        print(f'\rCompleted: {label}',end='')
        count+=1
    random.shuffle(dataset)
    X, y = zip(*dataset)

    return np.array(X),np.array(y)

# %%
# Convert image data to arrays and image label to numbers
X, y = input_target_split('rockpaperscissors',labels)
# Out:
# Completed: rock

# %% [markdown]
# ## Check the Data by Visualization

# %%
plt.figure(figsize = (15 , 9))
n = 0
for i in range(15):
    n+=1
    plt.subplot(5 , 5, n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.3)
    plt.imshow(X[i])
    plt.title(f'Label: {labels[y[i]]}')

# %% [markdown]
# ## Split Data into Train Set and Test Set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42) # 40% of dataset are Test Set

# %%
# One-Hot Encoding
y_train = np.eye(nb)[y_train]
y_test = np.eye(nb)[y_test]

# %% [markdown]
# ## Image Augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Image Augmentation for Train Data
train_datagen = ImageDataGenerator(
    rotation_range=45,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest',
    )

test_datagen = ImageDataGenerator()

train_datagen.fit(X_train)
test_datagen.fit(X_test)

# %% [markdown]
# ## Define the model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(512, activation='relu'),
    Dense(3, activation='softmax')
])

# %%
from keras.utils import plot_model
from IPython.display import Image
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
Image(filename='model_plot.png')

# %% [markdown]
# ## Compile and Train the Model

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Define Callback Class
from keras.callbacks import Callback

class StopTrainingCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('accuracy') >= 0.99:
            print("\nReached 99% accuracy. Stopping training...")
            self.model.stop_training = True

# %%
hist = model.fit_generator(train_datagen.flow(X_train,y_train,batch_size=32),
                                        validation_data=test_datagen.flow(X_test,y_test,batch_size=50),
                                        epochs=30,
                                        callbacks=[StopTrainingCallback()]
                           )
# Out:
# <ipython-input-16-4be7a92bb4df>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   hist = model.fit_generator(train_datagen.flow(X_train,y_train,batch_size=32),
# Epoch 1/30
# 41/41 [==============================] - 15s 222ms/step - loss: 1.2099 - accuracy: 0.4291 - val_loss: 0.9560 - val_accuracy: 0.5651
# Epoch 2/30
# 41/41 [==============================] - 7s 178ms/step - loss: 1.0191 - accuracy: 0.4855 - val_loss: 0.7779 - val_accuracy: 0.7865
# Epoch 3/30
# 41/41 [==============================] - 8s 197ms/step - loss: 0.8210 - accuracy: 0.6380 - val_loss: 0.4284 - val_accuracy: 0.8858
# Epoch 4/30
# 41/41 [==============================] - 7s 170ms/step - loss: 0.6622 - accuracy: 0.7127 - val_loss: 0.3026 - val_accuracy: 0.9144
# Epoch 5/30
# 41/41 [==============================] - 8s 196ms/step - loss: 0.6088 - accuracy: 0.7530 - val_loss: 0.3722 - val_accuracy: 0.8801
# Epoch 6/30
# 41/41 [==============================] - 8s 196ms/step - loss: 0.5693 - accuracy: 0.7492 - val_loss: 0.3276 - val_accuracy: 0.9018
# Epoch 7/30
# 41/41 [==============================] - 7s 178ms/step - loss: 0.5252 - accuracy: 0.7706 - val_loss: 0.2731 - val_accuracy: 0.9053
# Epoch 8/30
# 41/41 [==============================] - 8s 189ms/step - loss: 0.5193 - accuracy: 0.7774 - val_loss: 0.2538 - val_accuracy: 0.9247
# Epoch 9/30
# 41/41 [==============================] - 8s 197ms/step - loss: 0.5289 - accuracy: 0.7767 - val_loss: 0.2456 - val_accuracy: 0.9258
# Epoch 10/30
# 41/41 [==============================] - 8s 202ms/step - loss: 0.4308 - accuracy: 0.8331 - val_loss: 0.1741 - val_accuracy: 0.9509
# Epoch 11/30
# 41/41 [==============================] - 8s 192ms/step - loss: 0.3725 - accuracy: 0.8430 - val_loss: 0.1553 - val_accuracy: 0.9578
# Epoch 12/30
# 41/41 [==============================] - 7s 173ms/step - loss: 0.3470 - accuracy: 0.8628 - val_loss: 0.1399 - val_accuracy: 0.9600
# Epoch 13/30
# 41/41 [==============================] - 8s 192ms/step - loss: 0.2873 - accuracy: 0.8841 - val_loss: 0.1183 - val_accuracy: 0.9692
# Epoch 14/30
# 41/41 [==============================] - 8s 195ms/step - loss: 0.2670 - accuracy: 0.9062 - val_loss: 0.0820 - val_accuracy: 0.9749
# Epoch 15/30
# 41/41 [==============================] - 7s 170ms/step - loss: 0.3186 - accuracy: 0.8765 - val_loss: 0.1896 - val_accuracy: 0.9532
# Epoch 16/30
# 41/41 [==============================] - 8s 194ms/step - loss: 0.2536 - accuracy: 0.8986 - val_loss: 0.1335 - val_accuracy: 0.9486
# Epoch 17/30
# 41/41 [==============================] - 8s 192ms/step - loss: 0.1363 - accuracy: 0.9512 - val_loss: 0.0710 - val_accuracy: 0.9817
# Epoch 18/30
# 41/41 [==============================] - 7s 168ms/step - loss: 0.1589 - accuracy: 0.9451 - val_loss: 0.1260 - val_accuracy: 0.9680
# Epoch 19/30
# 41/41 [==============================] - 8s 185ms/step - loss: 0.1175 - accuracy: 0.9581 - val_loss: 0.0659 - val_accuracy: 0.9829
# Epoch 20/30
# 41/41 [==============================] - 8s 192ms/step - loss: 0.1012 - accuracy: 0.9672 - val_loss: 0.0566 - val_accuracy: 0.9863
# Epoch 21/30
# 41/41 [==============================] - 8s 192ms/step - loss: 0.1550 - accuracy: 0.9512 - val_loss: 0.0556 - val_accuracy: 0.9886
# Epoch 22/30
# 41/41 [==============================] - 7s 170ms/step - loss: 0.1441 - accuracy: 0.9573 - val_loss: 0.1630 - val_accuracy: 0.9452
# Epoch 23/30
# 41/41 [==============================] - 8s 195ms/step - loss: 0.1273 - accuracy: 0.9489 - val_loss: 0.0797 - val_accuracy: 0.9795
# Epoch 24/30
# 41/41 [==============================] - 8s 192ms/step - loss: 0.1275 - accuracy: 0.9558 - val_loss: 0.0700 - val_accuracy: 0.9852
# Epoch 25/30
# 41/41 [==============================] - 7s 170ms/step - loss: 0.0826 - accuracy: 0.9748 - val_loss: 0.0371 - val_accuracy: 0.9920
# Epoch 26/30
# 41/41 [==============================] - 7s 170ms/step - loss: 0.1030 - accuracy: 0.9627 - val_loss: 0.0570 - val_accuracy: 0.9897
# Epoch 27/30
# 41/41 [==============================] - 8s 191ms/step - loss: 0.0687 - accuracy: 0.9733 - val_loss: 0.0447 - val_accuracy: 0.9897
# Epoch 28/30
# 41/41 [==============================] - 7s 169ms/step - loss: 0.0839 - accuracy: 0.9718 - val_loss: 0.0334 - val_accuracy: 0.9920
# Epoch 29/30
# 41/41 [==============================] - 8s 192ms/step - loss: 0.0651 - accuracy: 0.9771 - val_loss: 0.0576 - val_accuracy: 0.9886
# Epoch 30/30
# 41/41 [==============================] - 8s 194ms/step - loss: 0.1207 - accuracy: 0.9611 - val_loss: 0.0705 - val_accuracy: 0.9829

# %%
# Clear session
# tf.keras.backend.clear_session()

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']

loss = hist.history['loss']
val_loss = hist.history['val_loss']

epochs_range = range(20)

#loss train & validation
plt.figure(figsize=(15,8))
plt.subplot(1, 2, 1)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Loss Plot')
plt.ylabel('Value')
plt.xlabel('Epoch')
plt.legend(loc="upper right")
plt.show()

#accuracy train & validation
plt.figure(figsize=(15,8))
plt.subplot(1, 2, 2)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.title('Accuracy Plot')
plt.ylabel('Value')
plt.xlabel('Epoch')
plt.legend(loc="lower right")
plt.show()

# %%
from google.colab import files
from keras.preprocessing import image
import matplotlib.image as mpimg

uploaded = files.upload()

for fn in uploaded.keys():
    path = fn
    img = image.load_img(path, target_size =(150,150))
    imgplot = plt.imshow(img)
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)

    images = np.vstack([x])
    classes = model.predict(images, batch_size=50)
    print(classes)
    print(fn)
    if classes[0][0]==1:
        print('paper')
    elif classes[0][1]==1:
        print('scissor')
    else:
        print('rock')

# %% [markdown]
# ## Save the Model

# %%
model.save('trained_model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## Load the Model

# %%
from keras.models import load_model

CNN_model = load_model('trained_model.h5')

# %%
y_pred = CNN_model.predict(X_test)
pred = np.argmax(y_pred,axis=1)
ground = np.argmax(y_test,axis=1)
# Out:
# 28/28 [==============================] - 1s 17ms/step

# %% [markdown]
# ## Model Report

# %%
from sklearn.metrics import classification_report

print(classification_report(ground,pred,target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#        paper       0.93      1.00      0.96       283
#     scissors       1.00      0.97      0.98       303
#         rock       1.00      0.96      0.98       290
#
#     accuracy                           0.98       876
#    macro avg       0.98      0.98      0.98       876
# weighted avg       0.98      0.98      0.98       876
